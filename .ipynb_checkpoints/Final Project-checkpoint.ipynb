# %%
import pandas as pd
import html5lib
import requests
import string
from bs4 import BeautifulSoup

# %%
url= 'http://www.acaloriecounter.com/fast-food.php'
r = requests.get(url)
soup = BeautifulSoup(r.content, 'html5lib')

# %%
# returns titles in a list named TABLE_TITLE.
TABLE_TITLE = []
for item in soup.find_all('h2'):
    TABLE_TITLE.append(item.text.rstrip('\n'))

# |REMOVING LAST TWO ROWS FROM THE TABLE TITLE LIST. #RETURNS COMPELTE LIST OF TITLE 
# |TABLES ON SITE.
TABLE_TITLE = TABLE_TITLE[:10]

# printing the results of the categories.
counter = 0
for title in TABLE_TITLE:
    counter += 1
    print 'Table #:| Category: '
    print counter,' :     ', title
    print '-'*70
    print '\n'
# Out:
# Table #:| Category:
# 1  :      French Fries (Large) Compared
# ----------------------------------------------------------------------
#
#
# Table #:| Category:
# 2  :      Hamburgers Compared
# ----------------------------------------------------------------------
#
#
# Table #:| Category:
# 3  :      Sandwiches/Hamburgers Compared
# ----------------------------------------------------------------------
#
#
# Table #:| Category:
# 4  :      Chicken (Individual Pieces) Compared
# ----------------------------------------------------------------------
#
#
# Table #:| Category:
# 5  :      Chicken Sandwiches Compared
# ----------------------------------------------------------------------
#
#
# Table #:| Category:
# 6  :      Onion Rings Compared
# ----------------------------------------------------------------------
#
#
# Table #:| Category:
# 7  :      Breakfast Sandwiches/Biscuits/Croissants/Wraps Compared
# ----------------------------------------------------------------------
#
#
# ...

# %%
TABLE_CATEGORIES = ['Restaurants',
             'Type',
             'Serving_Size',
             'Calories',
             'Total_Fat',
             'Saturated_Fat',
             'Trans_Fat',
             'Carbs',
             'Sodium'
            ]

# %%
TABLES_DATA = []
for tables in soup.find_all("table"):
    table_data = []
    for rows in tables.find('tbody'):
        for items in rows:
            for text in items:
                if text == ' ':
                    pass
                elif text == '\n':
                    pass
                else:
                    print [text]
# Out:
# [u"McDonald's"]
# [u'Regular']
# [u'\t']
# [u'170']
# [u'\t']
# [u'570']
# [u'30']
# [u'6']
# [u'8']
# [u'70']
# [u'330']
# [u'Burger King']
# [u'\t']
# [u'Regular']
# [u'160']
# [u'500']
# [u'28']
# [u'6']
# [u'6']
# [u'57']
# [u'820']
# [u'Burger King']
# [u'\t']
# [u'Salt Not Added']
# [u'160']
# [u'500']
# [u'28']
# [u'6']
# [u'6']
# [u'57']
# [u'530']
# [u"Wendy's"]
# [u'\t']
# [u'Regular']
# [u'Unknown']
# [u'540']
# [u'26']
# [u'4']
# [u'1']
# [u'69']
# [u'550']
# [u"Arby's"]
# [u'\t']
# [u'Homestyle']
# [u'213']
# [u'566']
# [u'37']
# [u'7']
# [u'1']
# [u'82']
# [u'1029']
# [u"Arby's"]
# [u'\t']
# [u'Curly']
# [u'198']
# [u'631']
# [u'37']
# [u'7']
# [u'1']
# [u'73']
# [u'1476']
# [u"Hardee's"]
# [u'\t']
# [u'Regular']
# [u'193']
# [u'610']
# [u'28']
# [u'6']
# [u'Unknown']
# [u'78']
# [u'370']
# [u"Hardee's"]
# [u'\t']
# [u'Crispy Curls']
# [u'153']
# [u'480']
# [u'23']
# [u'6']
# [u'Unknown']
# [u'60']
# [u'1190']
# [u'A&W']
# [u'\t']
# [u'Regular']
# [u'156']
# [u'430']
# ...

# %%
for row in soup.find_all("tr"):
    col = soup.find_all("td")
    
    if col:
        
        column_1 = col[0].text.strip()
        Resturants.append(column_1)

        column_2 = col[1].text.strip()
        Type.append(column_2)

        column_3 = col[2].text.strip()
        Serving_Size.append(column_3)

        column_4 = col[3].text.strip()
        Calories.append(column_4)
        
        column_5 = col[4].text.strip()
        Total_Fat.append(column_4)
        
        column_6 = col[5].text.strip()
        Saturated_Fat.append(column_4)
        
        column_7 = col[6].text.strip()
        Trans_Fat.append(column_4)

        column_8 = col[7].text.strip()
        Carbs.append(column_4)
        
        column_9 = col[8].text.strip()
        Sodium.append(column_4)

# %%
columns = {'Resturants': Resturants, 'Type': Type, 'Serving Size': Serving_Size, 'Calories': Calories, 'Total_Fat': Total_Fat
          "Saturated Fat": Saturated_Fat, "Trans_Fat": Trans_Fat, "Carbs": Carbs, "Sodium": Sodium}
df = pd.DataFrame(columns)
df
